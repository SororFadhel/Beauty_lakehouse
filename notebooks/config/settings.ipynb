# %% [markdown]
# # Global Configuration Settings
# This notebook defines shared paths and configuration variables used across all project notebooks.

# %%
# ============================================================
#  CONFIGURATION – BEAUTY LAKEHOUSE (TEAM VERSION)
# ============================================================

# ------------------------------------------------------------
# 1. Shared Volume paths (used by Notebook 1 ingestion)
# ------------------------------------------------------------
# These paths point to curated Delta files stored in the shared
# Unity Catalog Volume created in 00_environment_setup.
# Only the ingestion notebook writes to these paths.
# All team members read from these paths.

volume_base_path = "/Volumes/workspace/beauty/data"

curated_customers_path     = f"{volume_base_path}/curated/customers"
curated_products_path      = f"{volume_base_path}/curated/products"
curated_orders_path        = f"{volume_base_path}/curated/orders"
curated_order_items_path   = f"{volume_base_path}/curated/order_items"

warehouse_fact_sales_path  = f"{volume_base_path}/warehouse/fact_sales"


# ------------------------------------------------------------
# 2. Unity Catalog table references (TEAM SHARED TABLES)
# ------------------------------------------------------------
# These are the official shared Delta tables for the project.
# Only the ingestion owner publishes tables here.
# All team members load data from these tables.

catalog_name = "beauty_catalog"

curated_schema   = "curated"
warehouse_schema = "warehouse"
analytics_schema = "analytics"   # optional

# Curated tables
curated_customers_table     = f"{catalog_name}.{curated_schema}.customers"
curated_products_table      = f"{catalog_name}.{curated_schema}.products"
curated_orders_table        = f"{catalog_name}.{curated_schema}.orders"
curated_order_items_table   = f"{catalog_name}.{curated_schema}.order_items"

# Warehouse tables
warehouse_fact_sales_table  = f"{catalog_name}.{warehouse_schema}.fact_sales"

print("Configuration loaded successfully.")
